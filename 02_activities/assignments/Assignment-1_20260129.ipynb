# %%
#Set up the environment
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
# Loading librararies for adding images
from PIL import Image # to open images
import requests # to get images from URLs
from io import BytesIO # to store images in memory

# %%
# Getting imgae from URL
from PIL import Image, ImageFile
import requests
from io import BytesIO

# %%
url = "https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png"

headers = {
    "User-Agent": "Mozilla/5.0",
    "Accept": "image/*,*/*;q=0.8",
    "Referer": "https://en.wikipedia.org/"
}

response=requests.get(url,headers=headers)
image_file=BytesIO(response.content)
image=Image.open(image_file)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=220x426>

# %%
x=np.array(['Luffy','Zoro','Nami','Usopp','Sanji'])
y1=np.array([110,180,240,99,220])
y2=np.array([170,100,90,120,50])

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(x, y2, color = "red")

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(x, y2, color = "red")
ax_image = fig.add_axes([0.1, # x coordinate (ON FIGURE, NOT AXES)
0.11, # y coordinate (ON FIGURE, NOT AXES)
0.15, # image width
0.35]) # image height

# %%
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2,
color = "red")
ax_image = fig.add_axes([0.1, 0.11, 0.15, 0.35])
ax_image.imshow(image)
ax_image.axis('off')  # to hide the axis
# Out:
# (np.float64(-0.5), np.float64(219.5), np.float64(425.5), np.float64(-0.5))

# %%
path = "/Users/tanveerrouf/Documents/Soc Phd/SOC Fall 2025/Data Science Certificate/visualization/02_activities/assignments"
filename = "/assignment_3_visualization.png"  # Define your filename here

plt.savefig(path + filename, dpi=300)

# %%
# Creating the environment for Slide#09
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
# Additional libraries Krystal Wang Suggested
import plotly.graph_objects as go
from wordcloud import WordCloud
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

# %%
# Loading data
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Basic plot
sns.set_style('whitegrid') # set the style
plt.figure(figsize=(10, 6)) # set the figure size
sns.lineplot(data=tips,      # specify data source
             x="total_bill", # define x variable
             y="tip",        # define y variable
             hue="smoker")   # define grouping variable
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tipgraph = sns.lineplot(data=tips,      # specify data source
             x="total_bill", # define x variable
             y="tip",        # define y variable
             hue="smoker")   # define grouping variable

# %%
sns.set_style('whitegrid') # set the style
plt.figure(figsize=(10, 6)) # set the figure size

tipgraph = sns.lineplot(data=tips,      # specify data source
             x="total_bill", # define x variable
             y="tip",        # define y variable
            linestyle='--', # define line style
            marker ='o',    # define marker style
            color='hotpink',  # define line color
            hue="smoker")   # define grouping variable 

tipgraph.set(title='Total Bill vs Tip Amount by Smoking Status',
       xlabel='Total Bill ($)',
       ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Total Bill vs Tip Amount by Smoking Status'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
tipgraph = sns.scatterplot(data=tips,      # specify data source
             x="total_bill", # define x variable
             y="tip",        # define y variable
             style="time", # define marker style by time status
             hue="day")   # define grouping variable

# %%
fig = plt.subplots(figsize=(10, 3))

tipgraph = sns.scatterplot(data=tips, x='total_bill',
y='tip', style = 'time', hue =
'day', palette = ['purple',
'hotpink', 'deepskyblue',
'yellowgreen'])

tipgraph.set(title='Tips vs. Total Bill',
xlabel='Total Bill ($)',
ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue='day', diag_kind='kde', markers=["o", "s", "D", "^"], height=2.5)

# %%
daysplot = sns.relplot( # relational plot
    data=tips, # data source
    x="total_bill", # x variable
    y="tip", # y variable
    hue="sex", # grouping variable
    col="day", # create separate plots for each day
    col_wrap=2, # number of plots per row
    size="size", # size variable
    sizes=(20, 200), # size range
    alpha=0.7, # transparency
    palette="muted", # color palette
    height=4, # height of each plot
    aspect=1 # aspect ratio
)

# %%
# Setting up Plotly environment
import plotly.express as px
import plotly.graph_objects as go # go is short for graph objects

# %%
x1 = np.array(['Luffy','Zoro','Nami','Usopp','Sanji'])
y1 = np.array([110,180,240,99,220])
y2 = np.array([170,100,90,120,50])

# %%
graph = go.Figure()
graph.add_trace(go.Bar(
    x=x1,
    y=y1,
    name='Universe Alpha',
    marker_color='indianred'
))
graph.add_trace(go.Bar(
    x=x1,
    y=y2,
    name='Universe Beta',
    marker_color='lightsalmon'
))

# %%
graph.update_layout(
    title='Pirate Scores Comparison',
    xaxis_title='Pirates',
    yaxis_title='Performance Score',
    barmode='group' # group bars side by side
)       

graph.show()

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(x=x1, y=y1, mode='markers', # we want points for a scatter plot
marker=dict(
size=15, # point size
color='hotpink', # point colour
opacity=1, # point transparency/alpha
line=dict(width=5, color='purple') # point outline
)))
graph.update_layout(
title='Interactive Pirate Plot',
xaxis_title='Pirates',
yaxis_title='Scores',
width=500, height=500)
graph.write_html("pirate_plot.html")

graph.show()

# %%
# Making word clouds
from wordcloud import WordCloud
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
on_bad_lines='skip')
df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# ...

# %%
# join all our text from each row from our quote column into a string
text = " ".join(each for each in df.quote)

# generate our wordcloud image
wordcloud = WordCloud(background_color="white",
colormap = 'inferno',
width=800, height=400).generate(text)

# use matplotlib syntax to put our image in a figure
fig, ax = plt.subplots(figsize=(7, 3))
ax.imshow(wordcloud, # remember 'imshow' from when we added pictures to our matplotlib axes
interpolation='bilinear', # this line helps smooth our image
alpha=0.8)  # set the transparency of the image
ax.axis("off")
# Out:
# (np.float64(-0.5), np.float64(799.5), np.float64(399.5), np.float64(-0.5))

# %%
# Making Venn Diagrams
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted 

# Define our sets
A = set(['apple', 'banana', 'watermelon'])
B = set(['pumpkin', 'blueberry', 'apple', 'key lime'])  

diagram = venn2_unweighted([A, B],
set_labels = ('Fruits', 'Pies'),
set_colors=("blue", "red"),
alpha=0.5)

diagram.get_label_by_id("10").set_text("n".join(A - B))
diagram.get_label_by_id("11").set_text("n".join(A & B))
diagram.get_label_by_id("01").set_text("n".join(B - A))

plt.show()
# Out:
# /Users/tanveerrouf/Documents/Soc Phd/SOC Fall 2025/Data Science Certificate/visualization/visualization-env/lib/python3.11/site-packages/matplotlib_venn/_util.py:32: UserWarning:
#
# venn2_unweighted is deprecated. Use venn2 with the appropriate layout_algorithm instead.
